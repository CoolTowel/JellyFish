# %%
import jerel
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits

from marvin.tools import Maps

with fits.open('./data/galaxies_sorted.fits') as hdulist:
    plateifu_list = hdulist[1].data['plateifu']
    
with fits.open('./data/angles.fits') as hdulist:
    angle_list = hdulist[1].data['col2']

angle_list[0] = -160
angle_list[11] = 110
angle_list[10] = 125
angle_list[12] = -70
angle_list[13] = -140

import warnings 
warnings.filterwarnings("ignore")
# Out:
# [INFO]: No release version set. Setting default to DR15

# %%
t= jerel.stat_list(plateifu_list, angle_list)

# %%
t
# Out:
# <Table length=23>
#  num     ifu_id   d_angle ...        t_median                asy
# int64    str11     int16  ...        float64               float64
# ----- ----------- ------- ... ---------------------- --------------------
#     0 8944-6101      -160 ...  8.932915747960781e+38  0.31615463849910197
#     1 8934-3701        40 ...  4.549316591998778e+38   0.5804900363580087
#     2 8932-12701      -25 ...  8.513648348300371e+37  0.46018704762697654
#     3 9876-3702      -120 ...  6.659946749962441e+38   0.2934317315864862
#     4 8932-3701       -90 ...  9.000853218586259e+38  0.25685831922758234
#     5 8950-12705      -20 ...   1.71628853251843e+38   0.3783628088339379
#     6 8950-1901      -130 ...  7.604432060367184e+38  0.15114236380706536
#     7 8931-3703        10 ...  1.521132303996211e+38  0.15814815520500747
#     8 9876-3703       180 ...  6.072444333578821e+37   0.2490745007244937
#     9 9863-12701      170 ... 1.2548382910652295e+38   0.1489044126350124
#   ...         ...     ... ...                    ...                  ...
#    13 8603-9102      -140 ... 4.8819533837655046e+38   0.3023864120732814
#    14 8604-9102        20 ... 1.5568217712400375e+39  0.23078714476148152
#    15 8550-3701       -20 ... 2.7962051349178982e+38 0.047817874380097006
#    16 8312-12703      -35 ...  5.380272692481759e+38  0.22910470846420283
#    17 9869-12702      -60 ... 2.4661956572754617e+38  0.18966519785730931
#    18 9869-9102       -10 ...  2.778822728116248e+37   0.1541476941477505
#    19 8550-6103       -10 ...  1.987173812438745e+38  0.24563844399917742
#    20 8978-9101       -40 ... 1.6056938424161558e+38  0.20309371501789608
#    21 8625-9102       150 ... 1.0568094503625011e+38  0.20530409272933817
#    22 8625-12702      -60 ... 1.6271625280168096e+38   0.3470360917436013

# %%
t.write('./stat/stat_4_16.fits', format='fits')
